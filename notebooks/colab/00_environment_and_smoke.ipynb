# %% [markdown]
# # DEPRECATED — NON-CANONICAL
# Do not execute this historical wrapper. Start only with `00_campaign_control.ipynb` and follow `docs/canonical-colab-runbook.md`.
#
# # EdgeGuard-Road environment and smoke wrapper
# This notebook only checks out reviewed source, installs it, and invokes package commands.

# %%
REPOSITORY_URL = "https://github.com/OWNER/edgeguard-road.git"
# Replace OWNER after the reviewed repository exists.
# !git clone {REPOSITORY_URL}
# %cd edgeguard-road

# %%
# !python -m pip install -e .

# %%
# !python -m edgeguard doctor --json

# %%
# !python -m edgeguard smoke --config configs/smoke.yaml --deterministic

# %%
# !pytest -q
